# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
EVBattery = pd.read_csv('smart_ev.csv')
EVBattery.head() # Here Yes Means 1 and No Means 0
# Out:
#                Time  Temperature (°C)  Charging Rate (A)  \
# 0  2024-05-01 08:00                25                 10
# 1  2024-05-01 09:00                30                  8
# 2  2024-05-01 10:00                20                 12
# 3  2024-05-01 11:00                35                  7
# 4  2024-05-01 12:00                25                  9
#
#    Discharging Rate (A)  State of Health (%)  Full Capacity Reached  \
# 0                     5                   95                      0
# 1                     6                   92                      0
# 2                     4                   97                      0
# 3                     7                   90                      0
# 4                     5                   94                      0
#
#    Critical Temperature Event
# 0                           0
# 1                           0
# 2                           0
# 3                           1
# 4                           0

# %%
# @title Temperature (°C)

from matplotlib import pyplot as plt
EVBattery['Temperature (°C)'].plot(kind='hist', bins=20, title='Temperature (°C)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Charging Rate (A)

from matplotlib import pyplot as plt
EVBattery['Charging Rate (A)'].plot(kind='hist', bins=20, title='Charging Rate (A)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Discharging Rate (A)

from matplotlib import pyplot as plt
EVBattery['Discharging Rate (A)'].plot(kind='hist', bins=20, title='Discharging Rate (A)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title State of Health (%)

from matplotlib import pyplot as plt
EVBattery['State of Health (%)'].plot(kind='hist', bins=20, title='State of Health (%)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Temperature (°C) vs Charging Rate (A)

from matplotlib import pyplot as plt
EVBattery.plot(kind='scatter', x='Temperature (°C)', y='Charging Rate (A)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Charging Rate (A) vs Discharging Rate (A)

from matplotlib import pyplot as plt
EVBattery.plot(kind='scatter', x='Charging Rate (A)', y='Discharging Rate (A)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Discharging Rate (A) vs State of Health (%)

from matplotlib import pyplot as plt
EVBattery.plot(kind='scatter', x='Discharging Rate (A)', y='State of Health (%)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title State of Health (%) vs Critical Temperature Event

from matplotlib import pyplot as plt
EVBattery.plot(kind='scatter', x='State of Health (%)', y='Critical Temperature Event', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Time vs Temperature (°C)

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Time']
  ys = series['Temperature (°C)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = EVBattery.sort_values('Time', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Time')
_ = plt.ylabel('Temperature (°C)')

# %%
# @title Time vs Charging Rate (A)

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Time']
  ys = series['Charging Rate (A)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = EVBattery.sort_values('Time', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Time')
_ = plt.ylabel('Charging Rate (A)')

# %%
# @title Time vs Discharging Rate (A)

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Time']
  ys = series['Discharging Rate (A)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = EVBattery.sort_values('Time', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Time')
_ = plt.ylabel('Discharging Rate (A)')

# %%
# @title Time vs State of Health (%)

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Time']
  ys = series['State of Health (%)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = EVBattery.sort_values('Time', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Time')
_ = plt.ylabel('State of Health (%)')

# %%
# @title Charging Rate (A)

from matplotlib import pyplot as plt
EVBattery['Charging Rate (A)'].plot(kind='line', figsize=(8, 4), title='Charging Rate (A)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Discharging Rate (A)

from matplotlib import pyplot as plt
EVBattery['Discharging Rate (A)'].plot(kind='line', figsize=(8, 4), title='Discharging Rate (A)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title State of Health (%)

from matplotlib import pyplot as plt
EVBattery['State of Health (%)'].plot(kind='line', figsize=(8, 4), title='State of Health (%)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # EDA

# %%
# to check the data using pairplot
sns.pairplot(EVBattery)

# %%
EVBattery_numeric = EVBattery.drop(columns=["Time"])               # with out time
sns.heatmap(EVBattery_numeric.corr())
# Out:
# <Axes: >

# %%
import datetime

def convert_timestamp(timestamp):
    date_time = datetime.datetime.strptime(timestamp, "%Y-%m-%d %H:%M")
    return date_time.timestamp()

EVBattery["Time"] = EVBattery["Time"].apply(convert_timestamp)
sns.heatmap(EVBattery.corr())
# Out:
# <Axes: >
